# %% [markdown]
# # ISE Software Testing: Lab 5

# %% [markdown]
# ## Property Testing
#
# In this lab, we're going to use a property-based testing library to test our code. By now, you're used to writing tests that check specific inputs and outputs. Property-based testing is a different approach to testing that allows you to specify properties that your code should satisfy, and then the testing library will generate random inputs and check that your code satisfies the properties for all of them.
#
# ### Setup
#
# First, let's install the `hypothesis` library (https://hypothesis.readthedocs.io/en/latest/). This is a property-based testing library for Python. It's not part of the standard library, so we need to install it separately.

# %%
# %pip install hypothesis

import math
import unittest
import typing
from hypothesis import given, strategies as st, Verbosity, settings
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: hypothesis in /home/eoin/.local/lib/python3.8/site-packages (6.92.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/eoin/.local/lib/python3.8/site-packages (from hypothesis) (23.1.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/eoin/.local/lib/python3.8/site-packages (from hypothesis) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0 in /home/eoin/.local/lib/python3.8/site-packages (from hypothesis) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### A Simple Example
#
# Let's start with a simple example! If we're checking that the `sin` function is working correctly, we might quickly run into a problem. Only a few inputs are easy to check by hand, while the rest are difficult to calculate. We can't just check that `sin(0) == 0` and `sin(1) == 1` and call it a day. Instead, we can exploit the fact that `sin` is periodic, and check that `sin(x) == sin(x + 2*pi)` for all `x`. This is a property that we expect `sin` to satisfy.

# %%
def run_test_case(test_case: typing.Type[unittest.TestCase]):
    """This is a helper function to run a test case in a Jupyter notebook."""
    suite = unittest.defaultTestLoader.loadTestsFromTestCase(test_case)
    unittest.TextTestRunner().run(suite)


class SineTest(unittest.TestCase):
    @given(st.floats(min_value=0, max_value=2 * math.pi))
    def test_sine(self, x):
        # The sine function is periodic with period 2*pi
        # Let's exploit this property to test the sine function
        self.assertAlmostEqual(math.sin(x), math.sin(x + 2 * math.pi), places=10)


run_test_case(SineTest)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.054s
#
# OK

# %% [markdown]
# ### A Useful Example
#
# Talk is cheap, let's try a more useful example. Remember `find_last` from the first lab? Finding a failing test case for that function was awkward, because we had to try a bunch of different inputs before we found one that failed. Let's try to use property-based testing to find a failing test case for `find_last`.
#
# This time around, we don't need to generate any inputs ourselves. We just need to specify the properties that we want our code to satisfy. In this case, we want to check that `find_last` satisfies some properties (commented in the source code below). In the code below, we also set the verbosity to `Verbosity.verbose` so that we can see the inputs that are being generated and tested.
#
# Run the code below. You should see a bunch of inputs being generated and tested. Eventually, you should see a failing test case. What is the failing test case? What is the expected output? What is the actual output? What is the difference between the expected and actual output?
#
# Fix the bug in `find_last` and re-run the code. You should see that all of the tests pass now.

# %%
def find_last(arr, y):
    """Find the index of the last occurrence of y in the given list."""
    for i in range(len(arr) - 1, 0, -1):
        if arr[i] == y:
            return i
    return -1


class FindLastTest(unittest.TestCase):
    @given(st.lists(st.integers()), st.integers())
    @settings(verbosity=Verbosity.verbose)
    def test_find_last(self, arr, y):
        # Find the last occurrence of y in arr
        last_index = find_last(arr, y)
        if last_index != -1:
            # Check that y is actually at that index in the array
            self.assertEqual(arr[last_index], y)
            # Check that there is no other occurrence of y after the last_index
            self.assertNotIn(y, arr[last_index + 1 :])
        else:
            # Check that there is no occurrence of y in arr
            self.assertNotIn(y, arr)


run_test_case(FindLastTest)
# Out:
# .
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[14933,
#      10334,
#      -177,
#      4550344568873485490,
#      1115,
#      -22623,
#      1698378323,
#      -32602,
#      6578],
#     y=-102,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-3313],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-3313],
#     y=-16315,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-3900276368412747488, 22764],
#     y=-16154,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=0,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-18019, 18811],
#     y=-1083805918,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[7282712766113595384,
#      31449,
#      52,
#      14829,
#      -20086,
#      26237,
#      -4667,
#      -9904,
#      -10,
#      -30190,
#      -12420,
#      -36],
#     y=-21092,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[25873, 103],
#     y=31449,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[25873, 103, 31449, -52, -1042, -7674, -99],
#     y=-2,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-30754, 1696772639, -30942],
#     y=-49,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-30754, 1696772639, -30942],
#     y=-49,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-30754, 101, 769],
#     y=-49,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-30754, 769, 769],
#     y=-49,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-30754, 769, 769],
#     y=-49,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-34, 769, 769],
#     y=-49,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-570, 109, 817225400],
#     y=55,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[2, 25193729, 903788544, -29, -89, 7273, 3752, -24609, -31854, 126],
#     y=-9729,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[31242,
#      61,
#      -19303,
#      -19907,
#      26462,
#      -52,
#      6207253217776984449,
#      -55,
#      82,
#      25,
#      -74],
#     y=-32262,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[31242,
#      61,
#      -19303,
#      -19907,
#      26462,
#      -52,
#      6207253217776984449,
#      -55,
#      82,
#      25,
#      -74],
#     y=-32262,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[122,
#      317,
#      -19303,
#      -19907,
#      26462,
#      -52,
#      6207253217776984449,
#      -55,
#      82,
#      25,
#      -74],
#     y=-32262,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[122, 317, -19303],
#     y=871,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[122, 317, 317],
#     y=871,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[31234, 61, 317],
#     y=871,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[31234, 61, 31234],
#     y=871,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-113, -70, -393827651],
#     y=9346,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-113, -70],
#     y=-393827651,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-113, -113],
#     y=-393827651,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-113, -113],
#     y=-393827651,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-113, -113],
#     y=-393827651,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[1904312448,
#      -384,
#      -17290,
#      120,
#      72,
#      -14853,
#      -1441,
#      -84,
#      26104,
#      127,
#      25286],
#     y=25393,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[1904312448,
#      127,
#      -17290,
#      120,
#      72,
#      -14853,
#      -1441,
#      -84,
#      26104,
#      127,
#      25286],
#     y=25393,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[29706, 6672490754250537638, -1573893817713048001, -54, 25312],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[29706, 6672490754250537638, -1573893817713048001, -54, 25312],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[29706, 6672490754250537638, -1573893817713048001, -54, 25312],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-1573893817713048001,
#      6672490754250537638,
#      -1573893817713048001,
#      -54,
#      25312],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-54, 6672490754250537638, -1573893817713048001, -54, 25312],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-54, -92, -11898, -384, 7928, 36370197543674592],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-54, -92, -11898, -384, 7928, 36370197543674592],
#     y=-21178,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-16472, 30977, -11041, 14358, -30815],
#     y=-1057645899,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[2524141694008303008,
#      -98,
#      -1518091742,
#      17,
#      31753,
#      -1831,
#      92,
#      62,
#      6725898759075951619,
#      -31947,
#      -32574,
#      -129374220,
#      19957],
#     y=-27837,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=13023,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=13023,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-2014420506,
#      -119920099923955148006616973109357180889,
#      26189,
#      -125,
#      -76,
#      -4693,
#      11823,
#      79,
#      -940439102720754707,
#      -1028815673,
#      11782,
#      -6281,
#      -1903,
#      -77],
#     y=-65,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-84,
#      2352973001288198476,
#      18166,
#      -9593,
#      12431,
#      29991,
#      11400,
#      94,
#      -6403185],
#     y=-57,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-17181,
#      -16,
#      -86786509583445518899235225910837863200,
#      -37646878648492546989566518365073220746,
#      -119,
#      -1785,
#      5769,
#      27492,
#      -18973,
#      1701,
#      105,
#      29842,
#      21542,
#      75],
#     y=-31,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-18973,
#      -16,
#      -86786509583445518899235225910837863200,
#      -37646878648492546989566518365073220746,
#      -119,
#      -1785,
#      5769,
#      27492,
#      -18973,
#      1701,
#      105,
#      29842,
#      21542,
#      75],
#     y=-31,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-98516054824299919362198761040994977836,
#      -22314,
#      -8323,
#      -37646878648492546989566518365073220746,
#      -119,
#      -1785,
#      5769,
#      27492,
#      -18973,
#      1701,
#      105,
#      29842,
#      21542,
#      75],
#     y=-31,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-29960,
#      -687621103,
#      -14169,
#      -62,
#      28973,
#      -55,
#      58,
#      110,
#      -26711,
#      -24002,
#      127,
#      -16729,
#      -23,
#      -31576,
#      -22643,
#      -25815,
#      29766,
#      -18451],
#     y=163280434944331193785272894910975847916,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-29960,
#      -687621103,
#      -14169,
#      -62,
#      28973,
#      -55,
#      58,
#      110,
#      -26711,
#      -24002,
#      127,
#      -16729,
#      -23,
#      -31576,
#      -22643,
#      -25815,
#      29766,
#      -18451],
#     y=163280434944331193785272894910975847916,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-31576,
#      -687621103,
#      -14169,
#      -62,
#      28973,
#      -55,
#      58,
#      110,
#      -26711,
#      -24002,
#      127,
#      -16729,
#      -23,
#      -31576,
#      -22643,
#      -25815,
#      29766,
#      -18451],
#     y=163280434944331193785272894910975847916,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[843162010, -68],
#     y=88736062,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[843162010, 843162010],
#     y=88736062,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[843162010, 843162010],
#     y=88736062,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[843162010, 843162010],
#     y=5,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=-106,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[3, -106, -2876, 14, -553, -48, 25899],
#     y=-28946,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[1, -106, -2876, 14, -553, -48, 25899],
#     y=-28946,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[1, -1],
#     y=-2876,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[3, -1],
#     y=-2876,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[3, -1],
#     y=-2876,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[50528384,
#      771,
#      -2876,
#      -98,
#      -301408557,
#      -94,
#      -20046,
#      1811,
#      -73,
#      -18967,
#      9142307642681005193,
#      53,
#      -25,
#      -30855,
#      -112,
#      -12066,
#      22882,
#      17643,
#      3161,
#      -66,
#      -14663,
#      31920,
#      26653,
#      -14810,
#      -9,
#      -1086],
#     y=-31936,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[1456112904227039835, 13337, 21095, 32, 9985, 30703],
#     y=4271,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=30905,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=-120,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-77],
#     y=4068,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=-77,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-77, -30662, -12, 17335, 32032],
#     y=56,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[32032, -30662, -12, 17335, 32032],
#     y=56,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[32032],
#     y=-12,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[32032, 32032, -12],
#     y=-25950,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[32032, -12, -12],
#     y=-25950,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[],
#     y=-940,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-940],
#     y=1855692459,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0,
#      463383357,
#      21397,
#      -11260,
#      -31057,
#      -9786,
#      7478108185603992551,
#      -32283,
#      31748,
#      -11643,
#      1183832316,
#      74115092013132031126666571019922724172,
#      14275,
#      110,
#      10693,
#      53,
#      -86,
#      78,
#      28169],
#     y=13963,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0, 463383357, -83, -3],
#     y=1,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0, 463383357, 1400963200],
#     y=1,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0, 463383357, 0],
#     y=1,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[0, 463383357, 463383357],
#     y=1,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-1801, -74, -127, -110, 33, 5, 15877, 11157],
#     y=-166034320610383164684298917155314988310,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-1801, -74, -127, 33, 33, 5, 15877, 11157],
#     y=-166034320610383164684298917155314988310,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-1801, 5, -127, 33, 33, 5, 15877, 11157],
#     y=-166034320610383164684298917155314988310,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-897, -252202700144411009, -8462593, -771],
#     y=386,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-58819329, 5, -1, 33, 0, 0, -14820, -55, 4063],
#     y=-1076570343,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[33, 5, -1, 33, 0, 0, -14820, -55, 4063],
#     y=-1076570343,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061],
#     y=-111,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061, -27061, -117, -58, -793],
#     y=107172369097298866643632375097702570979,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061, -27061, -117, -27061, -793],
#     y=107172369097298866643632375097702570979,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061, -117, -117, -27061, -793],
#     y=107172369097298866643632375097702570979,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061,
#      -117,
#      -117,
#      -27061,
#      -793,
#      -27061,
#      107172369097298866643632375097702570979,
#      -18181,
#      30007,
#      9185,
#      -23666,
#      -22496,
#      -136504815877279050624869146448011256846,
#      -24,
#      7121,
#      -122,
#      -25840,
#      -161622094231723449695861103406753541833],
#     y=122,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061,
#      -117,
#      -117,
#      -27061,
#      3,
#      -361,
#      107172369097298866643632375097702570979,
#      -18181,
#      30007,
#      9185,
#      -23666,
#      -22496,
#      -136504815877279050624869146448011256846,
#      -24,
#      7121,
#      -122,
#      -25840,
#      -161622094231723449695861103406753541833],
#     y=122,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-27061,
#      -117,
#      -117,
#      -27061,
#      3,
#      -105,
#      107172369097298866643632375097702570979,
#      -18181,
#      30007,
#      9185,
#      -23666,
#      -22496,
#      -136504815877279050624869146448011256846,
#      -24,
#      7121,
#      -122,
#      -25840,
#      -161622094231723449695861103406753541833],
#     y=122,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-109, 25777, -21312, 8483, 30174, -21144, -11670, -28, 96],
#     y=5972158785736799132,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-11807],
#     y=27871,
# )
# Trying example: test_find_last(
#     self=<__main__.FindLastTest testMethod=test_find_last>,
#     arr=[-11807],
#     y=27871,
# )
# ----------------------------------------------------------------------
# Ran 1 test in 0.092s
#
# OK
